# %%
import pandas  as pd
import numpy as np
import missingno as msno


pd.set_option('display.max_column', 999)

# %%
train = pd.read_csv(r'./Data/data_exploration/train.csv')
test = pd.read_csv(r'./Data/data_exploration/test.csv')

# %%
train.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
print(train['GarageType'].unique())
print(train.groupby('GarageType').count()['Id'])
# Out:
# ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
# GarageType
# 2Types       6
# Attchd     870
# Basment     19
# BuiltIn     88
# CarPort      9
# Detchd     387
# Name: Id, dtype: int64

# %%
train.shape, test.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
numeric_features = train.select_dtypes(include=[np.number])
numeric_features.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
categorical_features = train.select_dtypes(include=[np.object])
categorical_features.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
# visualize the missing values fo a sample fo 250
msno.matrix(train, labels=True)

# %%
train.sample?

# %%
msno.heatmap?

# %%
import seaborn as sns
sns.heatmap(train.isnull())#, cbar=False)

# %%
msno.heatmap(train, cmap='plasma',inline=True)

# %%
msno.bar(train, sort=True )#filter=categorical_features.columns)# rotation=90)

# %%
train['Fireplaces'].dtype
# Out:
# dtype('int64')

# %% [markdown]
#  __ Dendrogram __
# The dendrogram allows you to more fully correlate variable completion, revealing trends deeper than the pairwise ones visible in the correlation heatmap:

# %%
msno.dendrogram(train,orientation='right')

# %%
# print(train.skew())
# print(train.kurt())
print(train.kurtosis())
# Out:
# Id                -1.200000
# MSSubClass         1.580188
# LotFrontage       17.452867
# LotArea          203.243271
# OverallQual        0.096293
# OverallCond        1.106413
# YearBuilt         -0.439552
# YearRemodAdd      -1.272245
# MasVnrArea        10.082417
# BsmtFinSF1        11.118236
# BsmtFinSF2        20.113338
# BsmtUnfSF          0.474994
# TotalBsmtSF       13.250483
# 1stFlrSF           5.745841
# 2ndFlrSF          -0.553464
# LowQualFinSF      83.234817
# GrLivArea          4.895121
# BsmtFullBath      -0.839098
# BsmtHalfBath      16.396642
# FullBath          -0.857043
# HalfBath          -1.076927
# BedroomAbvGr       2.230875
# KitchenAbvGr      21.532404
# TotRmsAbvGrd       0.880762
# Fireplaces        -0.217237
# GarageYrBlt       -0.418341
# GarageCars         0.220998
# GarageArea         0.917067
# WoodDeckSF         2.992951
# OpenPorchSF        8.490336
# EnclosedPorch     10.430766
# 3SsnPorch        123.662379
# ScreenPorch       18.439068
# ...

# %%
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
y = train['SalePrice']
plt.figure(1); plt.title('Johnson SU')
sns.distplot(y, kde=False, fit=st.johnsonsu)#, norm_hist=None)
plt.figure(2); plt.title('Normal')
sns.distplot(y, kde=False, fit=st.norm)#, norm_hist=None)
plt.figure(3); plt.title('Log Normal')
sns.distplot(y, kde=False, fit=st.lognorm)#, norm_hist=None)
# Out:
# C:\Users\amitkumar_kataria\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\amitkumar_kataria\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\amitkumar_kataria\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(train.skew(), color='blue', axlabel='Skewness')
# Out:
# C:\Users\amitkumar_kataria\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(12,8))
sns.distplot(train.kurt(), color='r', axlabel='Kurtosis', norm_hist=False, kde=True, rug=False)
# Out:
# C:\Users\amitkumar_kataria\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.hist(train['SalePrice'],)
plt.show()

# %%
target = np.log(train['SalePrice'])
target.skew()
plt.hist(target)
# Out:
# (array([  5.,  12.,  54., 184., 470., 400., 220.,  90.,  19.,   6.]),
#  array([10.46024211, 10.7676652 , 11.07508829, 11.38251138, 11.68993448,
#         11.99735757, 12.30478066, 12.61220375, 12.91962684, 13.22704994,
#         13.53447303]),
#  <a list of 10 Patch objects>)

# %%
correlation = numeric_features.corr()
print(correlation['SalePrice'].sort_values(ascending=False))
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
categorical_correlation = categorical_features.corr()
# print(categorical_correlation['SalePrice'].sort_values(ascending=False))

# %% [markdown]
# ###  Correlation Study -- Detections
# To explore further we will start with the following visualisation methods to analyze the data better:
#
# 1. Correlation Heat Map
# 2. Zoomed Heat Map
# 3. Pair Plot
# 4. Scatter Plot

# %%
f, ax = plt.subplots(figsize=(14,12))
plt.title('Correlation of Numeric Features with Sale Price',y=1, size=16)
sns.heatmap(correlation, square=True, vmax= 0.8)

# %% [markdown]
# ###  Zoomed HeatMap
#
# __ SalePrice Correlation matrix __

# %%
k = 11
cols = correlation.nlargest(k, 'SalePrice')['SalePrice'].index
print(cols)
cm = np.corrcoef(train[cols].values.T)
# print(cm)
f, ax = plt.subplots(figsize=(14,12))
sns.heatmap(cm, vmax=0.8, linewidths=0.01, square=True,annot=True, cmap='viridis',
            linecolor="white",xticklabels = cols.values ,annot_kws = {'size':12},yticklabels = cols.values)
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
#        'YearRemodAdd'],
#       dtype='object')

# %% [markdown]
# ### Pair plot
# Visualisation of 'OverallQual','TotalBsmtSF','GrLivArea','GarageArea','FullBath','YearBuilt','YearRemodAdd' features with respect to SalePrice in the form of pair plot & scatter pair plot for better understanding.

# %%
sns.set()
columns = ['SalePrice','OverallQual','TotalBsmtSF','GrLivArea','GarageArea','FullBath','YearBuilt','YearRemodAdd']
sns.pairplot(train[columns],size = 2 ,kind ='scatter',diag_kind='kde')
plt.show()

# %% [markdown]
# ###  Scatter Plot
# Scatter plots between the most correlated variables

# %%
fig, ((ax1,ax2),(ax3,ax4), (ax5,ax6)) = plt.subplots(nrows=3, ncols=2, figsize=(20,18))
sns.regplot(x='OverallQual', y='SalePrice', data=train, scatter=True, fit_reg=True, ax=ax1)
sns.regplot(x='TotalBsmtSF', y='SalePrice', data=train, scatter=True, fit_reg=True, ax=ax2)
sns.regplot(x='GrLivArea', y='SalePrice', data=train, scatter=True, fit_reg=True, ax=ax3)
sns.regplot(x='GarageArea', y='SalePrice', data=train, scatter=True, fit_reg=True, ax=ax4)
sns.regplot(x='FullBath', y='SalePrice', data=train, scatter=True, fit_reg=True, ax=ax5)
sns.regplot(x='YearBuilt', y='SalePrice', data=train, scatter=True, fit_reg=True, ax=ax6)

YearRemodAdd_scatter_plot = pd.concat([train['SalePrice'],train['YearRemodAdd']],axis = 1)
YearRemodAdd_scatter_plot.plot.scatter('YearRemodAdd','SalePrice')

# fig1 = plt.subplot()
# plt.scatter(x='YearRemodAdd', y='SalePrice',data=train)
# plt.xlabel('YearRemodAdd')
# plt.ylabel('SalePrice')
# plt.show()
# sns.regplot('Year')
# sns.regplot(x='YearRemodAdd', y='SalePrice', data=train, scatter=True, ax=ax8)

# %% [markdown]
# #### Pivoting -

# %%
train.pivot_table?

# %%
saleprice_overall_quality = train.pivot_table(index='OverallQual',
                                              values='SalePrice',
                                              aggfunc='median')
saleprice_overall_quality.plot(kind='bar',color='blue')
plt.xlabel('Overall Quality')
plt.ylabel('Median Sale Price')
plt.show()

# %%
f, ax=plt.subplots(figsize=(12,8))
fig = sns.boxplot(x='OverallQual',y='SalePrice', data=train)
fig.axis(ymin=0, ymar=800000)
# Out:
# (-0.5, 9.5, 0, 791005.0)

# %%
f, ax=plt.subplots(figsize=(12,8))
fig = sns.boxplot(x='Neighborhood',y='SalePrice', data=train)
fig.axis(ymin=0, ymar=800000)
xt = plt.xticks(rotation=45)

# %% [markdown]
# #####  Count Plot - Neighborhood

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Neighborhood', data=train)
xt = plt.xticks(rotation=45)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null category
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null category
# Alley            1460 non-null category
# LotShape         1460 non-null category
# LandContour      1460 non-null category
# Utilities        1460 non-null category
# LotConfig        1460 non-null category
# LandSlope        1460 non-null category
# Neighborhood     1460 non-null category
# Condition1       1460 non-null category
# Condition2       1460 non-null category
# BldgType         1460 non-null category
# HouseStyle       1460 non-null category
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# ...

# %%
# train['SaleCondition'] = train['SaleCondition'].astype('category')
train['SaleCondition']
# Out:
# 0        Normal
# 1        Normal
# 2        Normal
# 3       Abnorml
# 4        Normal
# 5        Normal
# 6        Normal
# 7        Normal
# 8       Abnorml
# 9        Normal
# 10       Normal
# 11      Partial
# 12       Normal
# 13      Partial
# 14       Normal
# 15       Normal
# 16       Normal
# 17       Normal
# 18       Normal
# 19      Abnorml
# 20      Partial
# 21       Normal
# 22       Normal
# 23       Normal
# 24       Normal
# 25       Normal
# 26       Normal
# 27       Normal
# 28       Normal
# 29       Normal
#          ...
# 1430     Normal
# 1431     Normal
# 1432     Normal
# 1433     Normal
# 1434     Normal
# 1435    Abnorml
# 1436     Normal
# 1437    Partial
# 1438     Normal
# 1439     Normal
# 1440     Normal
# 1441     Normal
# 1442     Normal
# 1443     Normal
# 1444     Normal
# 1445     Normal
# 1446     Normal
# 1447     Normal
# 1448     Normal
# 1449    Abnorml
# 1450     Normal
# 1451    Partial
# 1452     Normal
# 1453    Abnorml
# ...

# %%
train['SaleCondition'].cat

# %%
# converting the dtype for categorical_featues to 'category' type
# and fillna --with a new category value like 'MISSING'

for c in categorical_features:
    train[c] = train[c].astype('category')
    if train[c].isnull().any():
        train[c] = train[c].cat.add_categories('MISSING')
        train[c] = train[c].fillna('MISSING')

# %%
pd.melt?

# %%
def boxplot(x,y,**kwargs):
    sns.boxplot(x=x,y=y)
    x = plt.xticks(rotation=90)
f = pd.melt(train, id_vars=['SalePrice'], value_vars=categorical_features)
g = sns.FacetGrid(f, col='variable', col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(boxplot, "value", "SalePrice")

# %%
# f

# %%
print(f.variable.unique().shape[0])
print(len(categorical_features.columns))
# Out:
# 43
# 43

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='SaleType', y='SalePrice', data=train)
xt == plt.xticks(rotation=45)
# Out:
# C:\Users\amitkumar_kataria\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   This is separate from the ipykernel package so we can avoid doing imports until
# False

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='SaleCondition', y='SalePrice', data=train)
xt == plt.xticks(rotation=45)
# Out:
# C:\Users\amitkumar_kataria\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   This is separate from the ipykernel package so we can avoid doing imports until
# False

# %%
sns.violinplot(x='Functional',y='SalePrice', data=train)

# %%
sns.factorplot(x='FireplaceQu', y='SalePrice', data=train, color = 'm',
               estimator = np.median, order = ['Ex', 'Gd', 'TA', 'Fa', 'Po'], size = 4.5,  aspect=1.35)

# %%
g = sns.FacetGrid(train, col='FireplaceQu', col_wrap=3, col_order=['Ex', 'Gd', 'TA', 'Fa', 'Po'])
g.map(sns.boxplot, 'Fireplaces', 'SalePrice', order=[1,2,3], palette='Set2')

# %% [markdown]
# ####   PointPlot

# %%
plt.figure(figsize=(12,8))
g1 = sns.pointplot(x='Neighborhood', y='SalePrice', data=train, hue='LotShape')
g1.set_xticklabels(g1.get_xticklabels(), rotation=90)
g1.set_title('Lotshape Base on Neighborhoo', fontsize=15)
g1.set_xlabel('Neighborhood')
g1.set_ylabel('Sale Price', fontsize=12)
# Out:
# Text(0,0.5,'Sale Price')

# %% [markdown]
# ###  Missing Value Analysis

# %%
total = numeric_features.isnull().sum().sort_values(ascending=False)
percent = (numeric_features.isnull().sum()/numeric_features.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total,percent], axis=1,join='outer',keys=['Total Missing Count', '% of Total Observations'])

missing_data.index.name = 'Numeric Feature'
missing_data.head(20)
# Out:
#                  Total Missing Count  % of Total Observations
# Numeric Feature
# LotFrontage                      259                 0.177397
# GarageYrBlt                       81                 0.055479
# MasVnrArea                         8                 0.005479
# BsmtFinSF1                         0                 0.000000
# LowQualFinSF                       0                 0.000000
# 2ndFlrSF                           0                 0.000000
# 1stFlrSF                           0                 0.000000
# TotalBsmtSF                        0                 0.000000
# BsmtUnfSF                          0                 0.000000
# BsmtFinSF2                         0                 0.000000
# SalePrice                          0                 0.000000
# BsmtFullBath                       0                 0.000000
# YearRemodAdd                       0                 0.000000
# YearBuilt                          0                 0.000000
# ...

# %%
missing_values= numeric_features.isnull().sum(axis=0).reset_index()
missing_values.columns = ['Column_name', 'missing_count']
missing_values = missing_values.loc[missing_values['missing_count']>0]
missing_values.sort_values(by='missing_count', inplace=True)

ind = np.arange(missing_values.shape[0])

width = 0.1
fig, ax = plt.subplots(figsize=(12,3))
rects = ax.barh(ind, missing_values.missing_count.values, color='b')

ax.set_yticks(ind)
ax.set_yticklabels(missing_values.Column_name.values, rotation='horizontal')
ax.set_xlabel('Missing ObservationCount')
ax.set_title('Missing Observations Count - Numeric Features')

plt.show()

# %%
missing_values
# Out:
#     Column_name  missing_count
# 8    MasVnrArea              8
# 25  GarageYrBlt             81
# 2   LotFrontage            259

# %% [markdown]
# ####  Missing value - Categorical Features

# %%
total = categorical_features.isnull().sum().sort_values(ascending=False)
percent = (categorical_features.isnull().sum()/categorical_features.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, join='outer',keys=['Total Missing Count', '% of Total Observations'])
missing_data.index.name = 'Feature'
missing_data.head(20)
# Out:
#               Total Missing Count  % of Total Observations
# Feature
# PoolQC                       1453                 0.995205
# MiscFeature                  1406                 0.963014
# Alley                        1369                 0.937671
# Fence                        1179                 0.807534
# FireplaceQu                   690                 0.472603
# GarageCond                     81                 0.055479
# GarageQual                     81                 0.055479
# GarageFinish                   81                 0.055479
# GarageType                     81                 0.055479
# BsmtFinType2                   38                 0.026027
# BsmtExposure                   38                 0.026027
# BsmtFinType1                   37                 0.025342
# BsmtQual                       37                 0.025342
# BsmtCond                       37                 0.025342
# MasVnrType                      8                 0.005479
# ...

# %%
missing_values = categorical_features.isnull().sum(axis=0).reset_index()
missing_values.columns = ['column_name', 'missing_count']
missing_values = missing_values.loc[missing_values['missing_count']>0]
missing_values = missing_values.sort_values(by='missing_count')

ind = np.arange(missing_values.shape[0])
width = 0.9
fig, ax = plt.subplots(figsize=(12,18))
rects = ax.barh(ind, missing_values.missing_count.values, color='red')
ax.set_yticks(ind)
ax.set_yticklabels(missing_values.column_name.values, rotation='horizontal')
ax.set_xlabel("Missing Observations Count")
ax.set_title("Missing Observations Count - Categorical Features")
plt.show()

# %% [markdown]
# #### Categorical Feature Exploration

# %%
# train.info()

# %%
train['Condition1'].dtype
# Out:
# CategoricalDtype(categories=['Artery', 'Feedr', 'Norm', 'PosA', 'PosN', 'RRAe', 'RRAn',
#                   'RRNe', 'RRNn'],
#                  ordered=False)

# %%
train['Condition1'].mode()
# Out:
# 0    Norm
# Name: Condition1, dtype: category
# Categories (9, object): [Artery, Feedr, Norm, PosA, ..., RRAe, RRAn, RRNe, RRNn]

# %%
for column_name in train.columns:
#     print(train[column_name].dtype)
#     print(train[column_name].dtypes)
    if train[column_name].dtypes == 'object':
        train[column_name] =train[column_name].fillna(
            train[column_name].mode().iloc[0])
        unique_category = len(train[column_name].unique())
        print("Feature '{column_name}' has '{unique_categor}'\
              unique categories".format(column_name = column_name, 
                                        unique_categor= unique_category))

# %%
for column_name in test.columns:
#     print(test[column_name].dtype)
#     print(test[column_name].dtypes)
    if test[column_name].dtypes == 'object':
        test[column_name] =test[column_name].fillna(
            test[column_name].mode().iloc[0])
        unique_category = len(test[column_name].unique())
        print("Feature '{column_name}' has '{unique_categor}'\
              unique categories".format(column_name = column_name, 
                                        unique_categor= unique_category))
# Out:
# Feature 'MSZoning' has '5'              unique categories
# Feature 'Street' has '2'              unique categories
# Feature 'Alley' has '2'              unique categories
# Feature 'LotShape' has '4'              unique categories
# Feature 'LandContour' has '4'              unique categories
# Feature 'Utilities' has '1'              unique categories
# Feature 'LotConfig' has '5'              unique categories
# Feature 'LandSlope' has '3'              unique categories
# Feature 'Neighborhood' has '25'              unique categories
# Feature 'Condition1' has '9'              unique categories
# Feature 'Condition2' has '5'              unique categories
# Feature 'BldgType' has '5'              unique categories
# Feature 'HouseStyle' has '7'              unique categories
# Feature 'RoofStyle' has '6'              unique categories
# Feature 'RoofMatl' has '4'              unique categories
# Feature 'Exterior1st' has '13'              unique categories
# ...

# %% [markdown]
# ### Reference
#
# Essential of Data exploration
#
# https://www.kaggle.com/pavansanagapati/a-simple-tutorial-on-exploratory-data-analysis
